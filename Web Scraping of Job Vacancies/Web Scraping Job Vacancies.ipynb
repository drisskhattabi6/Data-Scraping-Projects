# %% [markdown]
# # Web Scraping Job Vacancies : from [Indeed website](www.indeed.com/)
#
# ### URL = https://www.indeed.com/jobs?q={query}&l={location}

# %% [markdown]
# ## Introduction
#
# In this project, we'll build a web scraper to extract job listings from a popular job search platform. We'll extract job titles, companies, locations, job descriptions, and other relevant information.
#
# Here are the main steps we'll follow in this project:
#
# 1. Write the Python code to extract job data from our job search platform
# 2. Save the data to a CSV file
#
# ## Prerequisites
#
# Before starting this project, you should have some basic knowledge of Python programming and HTML structure. In addition, you need to create Scrapfly account to get API key, and you will use the following packages in your Python environment:
#
# - scrapfly-sdk
# - BeautifulSoup
# - csv
# - markdownify
# - pandas
#
# you can install additional packages using `!pip install packagename` :
#
# - `!pip install scrapfly-sdk`
# - `!pip install BeautifulSoup`
# - `!pip install pandas`
# - `!pip install markdownify`

# %%
# Importing Required Libraries
from scrapfly import ScrapflyClient, ScrapeConfig
from bs4 import BeautifulSoup
import pandas as pd
import re
from markdownify import markdownify as md

# %%
# f"https://www.linkedin.com/jobs/search?keywords={query}&location={location}"
def get_html_content(url):
    client = ScrapflyClient(key="YOUR Scrapfly API KEY")
    result = client.scrape(ScrapeConfig(url= url, asp=True,))
    return result.content

# asp=True => enable Anti Scraping Protection

# %%
query = "data analytic"
location = "USA"
url= f"https://www.indeed.com/jobs?q={query}&l={location}"

search_result = get_html_content(url)

# Parsing the webpage content
soup = BeautifulSoup(search_result, 'html.parser')

jobs_container = soup.find('div', {'id': 'mosaic-provider-jobcards'})

all_jobs = jobs_container.find_all('li')

table_content = []

for row in all_jobs:
    td = row.find('td', {'class': 'resultContent'})
    
    if not td :
        continue
    #---------------------------
    job_info= td.find('h2', {'class': 'jobTitle'})
    job_link = job_info.find('a').attrs['href']
    job_title = job_info.text.strip()
    #---------------------------
    div_company_location = td.find('div', {'class': 'company_location'})
    company_name = div_company_location.find('span', {'data-testid': 'company-name'}).text.strip()
    location = div_company_location.find('div', {'data-testid': 'text-location'}).text.strip()
    #---------------------------
    posted_date =  td.find('div', {'class': 'jobMetaDataGroup'})
    posted_date = posted_date.find('span', {'data-testid': 'myJobsStateDate'}).text.strip()
    posted_date = re.sub(r'Posted', '', posted_date).strip()
    #---------------------------
    job_detail = get_html_content(f"https://www.indeed.com{job_link}")
    soup2 = BeautifulSoup(job_detail, 'html.parser')
    #---------------------------
    salaryInfoAndJobType = soup2.find('div', {'id': 'salaryInfoAndJobType'})
    if salaryInfoAndJobType :
        salaryInfoAndJobType = salaryInfoAndJobType.find_all('span')
        salaryInfo = None

        if len(salaryInfoAndJobType) == 1 :
            jobType = salaryInfoAndJobType[0].text.strip()
        else :
            salaryInfo = salaryInfoAndJobType[0].text.strip()
            jobType = salaryInfoAndJobType[1].text.strip()
    #---------------------------
    job_benefits_container = soup2.find('div', {'id': 'benefits'})
    job_benefits = None
    if job_benefits_container : 
        job_benefits_list = job_benefits_container.find_all('li')
        job_benefits = [text.text.strip() for text in job_benefits_list]
    #---------------------------
    job_description_container = soup2.find('div', {'id': 'jobDescriptionText'})
    # Convert HTML to Markdown
    job_description = md(str(job_description_container))
    #---------------------------
    print("job title : ", job_title)
    print('-'*50)
    
    table_content.append({
        'job title': job_title,
        'job link': f"https://www.indeed.com{job_link}",
        'company name': company_name,
        'location': location,
        'posted date': posted_date,
        'salary Info': salaryInfo,
        'job Type': jobType,
        'job description': job_description,
    })
# Out:
# job title :  Data Analytics Specialist
# --------------------------------------------------
# job title :  Audit Data Scientist
# --------------------------------------------------
# job title :  Molecular Breeding Data Analyst (McClean)
# --------------------------------------------------
# job title :  Data Reporting and Analytics Consultant IV - SQL, Tableau
# --------------------------------------------------
# job title :  Senior Data Analyst
# --------------------------------------------------
# job title :  Manager, Data Reporting and Analytics - Python, Tableau, SQL
# --------------------------------------------------
# job title :  Data Reporting and Analytics Consultant V, Programming
# --------------------------------------------------
# job title :  Data Scientist
# --------------------------------------------------
# job title :  Behavioral Data Scientist
# --------------------------------------------------
# job title :  Cloud Data Analytics Specialist
# --------------------------------------------------
# job title :  Crew Scheduler
# --------------------------------------------------
# job title :  Quality Data Analyst | Clinical Analytics | Days
# --------------------------------------------------
# job title :  Data Analyst IV
# --------------------------------------------------
# job title :  Medicaid Data Analyst
# --------------------------------------------------
# job title :  Client Data Account Maintenance, Associate
# --------------------------------------------------

# %%
print(f"Number of Jobs Found : {len(table_content)}")
# Out:
# Number of Jobs Found : 15

# %%
data = pd.DataFrame(table_content) 
data
# Out:
#                                             job title  \
# 0                           Data Analytics Specialist
# 1                                Audit Data Scientist
# 2           Molecular Breeding Data Analyst (McClean)
# 3   Data Reporting and Analytics Consultant IV - S...
# 4                                 Senior Data Analyst
# 5   Manager, Data Reporting and Analytics - Python...
# 6   Data Reporting and Analytics Consultant V, Pro...
# 7                                      Data Scientist
# 8                           Behavioral Data Scientist
# 9                     Cloud Data Analytics Specialist
# 10                                     Crew Scheduler
# 11   Quality Data Analyst | Clinical Analytics | Days
# 12                                    Data Analyst IV
# 13                              Medicaid Data Analyst
# 14         Client Data Account Maintenance, Associate
#
#                                              job link  \
# 0   https://www.indeed.com/rc/clk?jk=d958dbc0f83a5...
# 1   https://www.indeed.com/rc/clk?jk=9a27035fd66e0...
# 2   https://www.indeed.com/rc/clk?jk=0c6e7ce0e9311...
# 3   https://www.indeed.com/rc/clk?jk=3773fbb1ac1ac...
# 4   https://www.indeed.com/rc/clk?jk=0843d5fec93c4...
# 5   https://www.indeed.com/rc/clk?jk=f7f2dc634f81b...
# 6   https://www.indeed.com/rc/clk?jk=91b8d9cff9d31...
# 7   https://www.indeed.com/rc/clk?jk=5f6d77ee91a9f...
# 8   https://www.indeed.com/rc/clk?jk=d499a5703adc7...
# 9   https://www.indeed.com/rc/clk?jk=4601949755650...
# 10  https://www.indeed.com/rc/clk?jk=06835bfe01ada...
# 11  https://www.indeed.com/rc/clk?jk=955c6fafb6154...
# 12  https://www.indeed.com/rc/clk?jk=a2f54b07f2ff4...
# 13  https://www.indeed.com/rc/clk?jk=097eb3370a99b...
# 14  https://www.indeed.com/rc/clk?jk=780b124b67845...
#
#                                company name  \
# 0   California State University, Long Beach
# 1            Logistics Management Institute
# 2             North Dakota State University
# 3                         Kaiser Permanente
# 4                         Tulane University
# 5                         Kaiser Permanente
# 6                         Kaiser Permanente
# 7                             Vizient, Inc.
# 8                                   Parsons
# 9            Logistics Management Institute
# 10                                     Wing
# 11                                UF Health
# 12                                    Akima
# 13                       Rutgers University
# 14                      JPMorgan Chase & Co
#
#                                           location   posted date  \
# 0   Long Beach, CA 90840 (State College Area area)   11 days ago
# 1                                           Remote    6 days ago
# 2                                        Fargo, ND   11 days ago
# 3                                      Oakland, CA    4 days ago
# 4                                  New Orleans, LA  30+ days ago
# 5                            Hyattsville, MD 20785   25 days ago
# 6                                    Santa Ana, CA    5 days ago
# 7                                      Chicago, IL    5 days ago
# 8                                  Springfield, VA  30+ days ago
# 9                                           Remote    6 days ago
# 10                     Dallas, TX (Oak Cliff area)   11 days ago
# 11                           Gainesville, FL 32608    3 days ago
# 12                            Washington, DC 20080  30+ days ago
# 13          Hybrid work in New Brunswick, NJ 08901   16 days ago
# 14                                 Plano, TX 75024   15 days ago
#
#                         salary Info                    job Type  \
# 0           $4,094 - $7,881 a month                -  Full-time
# 1                              None                   Full-time
# 2             Desde $80,000 por año                -  Full-time
# 3       $127,600 - $165,110 por año                -  Full-time
# 4       $127,600 - $165,110 por año                -  Full-time
# 5        $133,500 - $172,700 a year                -  Full-time
# 6        $141,600 - $183,150 a year                -  Full-time
# 7                              None  $77,400 - $127,600 por año
# 8        $96,400 - $168,700 por año                -  Full-time
# 9                              None                   Full-time
# 10      $112,000 - $126,000 por año                 -  Contract
# 11  $77,272.00 - $132,849.60 a year                -  Full-time
# 12       $115,000 - $125,000 a year                -  Full-time
# 13       $100,485 - $121,582 a year     -  Part-time, Full-time
# 14                             None                   Full-time
#
#                                       job description
# 0   \n\n\n**Job no:** 541893  \n **Work type:** St...
# 1   \n Overview: \n \n LMI is seeking for a **Audi...
# 2   \n\n\n\n**Description \& Details:**\n\n\nNDSU ...
# 3   \n\n\n**Remote from any KP location in CA, OR,...
# 4   \n\n\n\n The Senior Data Analyst at the Cowen ...
# 5   \n\n**Job Summary:**\n   \n This manager level...
# 6   \n\n**Job Summary:**\n   \n In addition to the...
# 7   \n\n\nWhen you’re the best, we’re the best. We...
# 8   \n In a world of possibilities, pursue one wit...
# 9   \n Overview: \n \n LMI is seeking for a **Audi...
# 10  \n\n**About Wing:**\n\n\nWing offers drone del...
# 11  \n Overview: \n  **Status: FULL\-TIME**\n\n\n ...
# 12  \n**Overview**\n\n\n**Work Where it Matters**\...
# 13  \n\n**Position Details**\n--------------------...
# 14  \n**JOB DESCRIPTION**\n  \n nterested in a new...

# %%
# saving data to csv file :
data.to_csv("indeed_jobs.csv")
